# %%
import numpy as np
import MDAnalysis as mda
import matplotlib.pyplot as plt
import nglview as nv

# %%
# %matplotlib notebook

# %%
# %pwd
# Out:
# '/home/chemistry/MD/dinucleotide_generator_test/2.GG/1.RNA'

# %%
# Loads just a .gro single-frame file and checks if there are positions and velocities
grofilename =   'confout_aligned.gro'; print(grofilename)
uframe = mda.Universe(grofilename)
print(uframe.trajectory.ts.has_positions)
print(uframe.trajectory.ts.has_velocities)

# Break out by resname or segid
SYSTEM = uframe.select_atoms('segid SYSTEM')

# Show the whole system
TOTview = nv.show_mdanalysis(uframe)
TOTview.clear()
TOTview.add_representation('ball+stick',selection='RNA')
TOTview.add_representation(repr_type='axes',showAxes=True)
TOTview.camera='orthographic'
TOTview.center()
TOTview.control.rotate([0,1,0,0])
TOTview
# Out:
# confout_aligned.gro
# True
# False
# /home/chemistry/.local/lib/python3.9/site-packages/MDAnalysis/topology/base.py:203: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   residx = np.zeros_like(criteria[0], dtype=np.int)
# /home/chemistry/.local/lib/python3.9/site-packages/MDAnalysis/core/selection.py:521: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros(len(group), dtype=np.bool)
# NGLWidget()

# %%
# Loads just a .gro single-frame file and checks if there are positions and velocities
grofilename =   'confout_rotated.gro'; print(grofilename)
uframe = mda.Universe(grofilename)
print(uframe.trajectory.ts.has_positions)
print(uframe.trajectory.ts.has_velocities)

# Break out by resname or segid
SYSTEM = uframe.select_atoms('segid SYSTEM')

# Show the whole system
TOTview = nv.show_mdanalysis(uframe)
TOTview.clear()
TOTview.add_representation('ball+stick',selection='RNA')
TOTview.add_representation(repr_type='axes',showAxes=True)
TOTview.camera='orthographic'
TOTview.center()
TOTview.control.rotate([0,1,0,0])
TOTview
# Out:
# confout_rotated.gro
# True
# False
# /home/chemistry/.local/lib/python3.9/site-packages/MDAnalysis/topology/base.py:203: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   residx = np.zeros_like(criteria[0], dtype=np.int)
# /home/chemistry/.local/lib/python3.9/site-packages/MDAnalysis/core/selection.py:521: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros(len(group), dtype=np.bool)
# NGLWidget()

# %%
# Loads just a .gro single-frame file and checks if there are positions and velocities
grofilename =   'confout_shifted.gro'; print(grofilename)
uframe = mda.Universe(grofilename)
print(uframe.trajectory.ts.has_positions)
print(uframe.trajectory.ts.has_velocities)

# Break out by resname or segid
SYSTEM = uframe.select_atoms('segid SYSTEM')

# Show the whole system
TOTview = nv.show_mdanalysis(uframe)
TOTview.clear()
TOTview.add_representation('ball+stick',selection='RNA')
TOTview.add_representation(repr_type='axes',showAxes=True)
TOTview.camera='orthographic'
TOTview.center()
TOTview.control.rotate([0,1,0,0])
TOTview
# Out:
# confout_shifted.gro
# True
# False
# /home/chemistry/.local/lib/python3.9/site-packages/MDAnalysis/topology/base.py:203: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   residx = np.zeros_like(criteria[0], dtype=np.int)
# /home/chemistry/.local/lib/python3.9/site-packages/MDAnalysis/core/selection.py:521: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros(len(group), dtype=np.bool)
# NGLWidget()
