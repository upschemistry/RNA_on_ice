# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import uniform_filter1d
from matplotlib import colors

# %%
OP_220K = np.loadtxt("traj_224K_equilibrate/SDOD.txt")
OP_245K = np.loadtxt("traj_245K_equilibrate/SDOD.txt")
